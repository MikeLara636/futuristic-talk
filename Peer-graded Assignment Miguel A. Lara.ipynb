# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Hi, my name is Miguel Lara** <br> My current job on week is stadistical analyst and bartender on weekends. I'd love to work as a data scientist in a great alcoholic beverages company

# %% [markdown]
# _I am interested in data science because I've always been inquisitive in finding hidden things. I find this work that looks like that of a detective diving into a sea of data to find a solution fascinating. I´m already working with data and i want to reach the next level_

# %% [markdown]
# ### In the next cell, my code will find the sum of my 3 dog's ages

# %%
5+2+1
# Out:
# 8

# %% [markdown]
# - Ginger is 5 years old
# - Tezca is 2 years old
# - Norbert is 1 year old
# 1. They love to run and find the ball
# 2. Norbert is the only male dog but also the shortest
# 3. Tezca knows how to climb
#
# | Name |Favorite food |
# | ----| ----|
# | Tezca   | Chicken |
# | Ginger | Bread |
# | Norby | eggs |
#
# ![tezca%20y%20gin.jpg](attachment:tezca%20y%20gin.jpg)
